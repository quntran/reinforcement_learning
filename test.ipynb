# %%
# !pip install gym[mujoco]
# Out:
# Requirement already satisfied: gym[mujoco] in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from gym[mujoco]) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from gym[mujoco]) (1.22.2)
# Collecting mujoco-py<2.0,>=1.50
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: glfw>=1.4.0 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[mujoco]) (2.5.0)
# Requirement already satisfied: Cython>=0.27.2 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[mujoco]) (0.29.28)
# Requirement already satisfied: imageio>=2.1.2 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[mujoco]) (2.16.0)
# Requirement already satisfied: cffi>=1.10 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[mujoco]) (1.15.0)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[mujoco]) (0.12.2)
# Requirement already satisfied: pycparser in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50->gym[mujoco]) (2.21)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\boba.vn\appdata\local\programs\python\python310\lib\site-packages (from imageio>=2.1.2->mujoco-py<2.0,>=1.50->gym[mujoco]) (9.0.1)
# Building wheels for collected packages: mujoco-py
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Failed to build mujoco-py
# Installing collected packages: mujoco-py
#   Running setup.py install for mujoco-py: started
#   Running setup.py install for mujoco-py: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       running bdist_wheel
#       running build
#
#       You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\Boba.vn\.mujoco\mjpro150
#
#       This package only provides python bindings, the library must be installed separately.
#
#       Please follow the instructions on the README to install MuJoCo
#
#           https://github.com/openai/mujoco-py#install-mujoco
#
#       Which can be downloaded from the website
#
#           https://www.roboti.us/index.html
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\setup.py", line 32, in <module>
#           setup(
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\__init__.py", line 153, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\core.py", line 148, in setup
#           dist.run_commands()
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 966, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 985, in run_command
#           cmd_obj.run()
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#           self.run_command('build')
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\cmd.py", line 313, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 985, in run_command
#           cmd_obj.run()
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\setup.py", line 28, in run
#           import mujoco_py  # noqa: force build
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\__init__.py", line 3, in <module>
#           from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\builder.py", line 502, in <module>
#           mjpro_path, key_path = discover_mujoco()
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\utils.py", line 93, in discover_mujoco
#           raise Exception(message)
#       Exception:
#       You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\Boba.vn\.mujoco\mjpro150
#
#       This package only provides python bindings, the library must be installed separately.
#
#       Please follow the instructions on the README to install MuJoCo
#
#           https://github.com/openai/mujoco-py#install-mujoco
#
#       Which can be downloaded from the website
#
#           https://www.roboti.us/index.html
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mujoco-py
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for mujoco-py did not run successfully.
#   │ exit code: 1
#   ╰─> [57 lines of output]
#       running install
#       running build
#
#       You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\Boba.vn\.mujoco\mjpro150
#
#       This package only provides python bindings, the library must be installed separately.
#
#       Please follow the instructions on the README to install MuJoCo
#
#           https://github.com/openai/mujoco-py#install-mujoco
#
#       Which can be downloaded from the website
#
#           https://www.roboti.us/index.html
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\setup.py", line 32, in <module>
#           setup(
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\__init__.py", line 153, in setup
#           return distutils.core.setup(**attrs)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\core.py", line 148, in setup
#           dist.run_commands()
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 966, in run_commands
#           self.run_command(cmd)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 985, in run_command
#           cmd_obj.run()
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\command\install.py", line 61, in run
#           return orig.install.run(self)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\command\install.py", line 568, in run
#           self.run_command('build')
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\cmd.py", line 313, in run_command
#           self.distribution.run_command(command)
#         File "C:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\distutils\dist.py", line 985, in run_command
#           cmd_obj.run()
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\setup.py", line 28, in run
#           import mujoco_py  # noqa: force build
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\__init__.py", line 3, in <module>
#           from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\builder.py", line 502, in <module>
#           mjpro_path, key_path = discover_mujoco()
#         File "C:\Users\Boba.vn\AppData\Local\Temp\pip-install-cv6ks283\mujoco-py_bd98841031fc43a785896491cb383d42\mujoco_py\utils.py", line 93, in discover_mujoco
#           raise Exception(message)
#       Exception:
#       You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\Boba.vn\.mujoco\mjpro150
#
#       This package only provides python bindings, the library must be installed separately.
#
#       Please follow the instructions on the README to install MuJoCo
#
#           https://github.com/openai/mujoco-py#install-mujoco
#
#       Which can be downloaded from the website
#
#           https://www.roboti.us/index.html
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> mujoco-py
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import random
import gym
from IPython import display as ipythondisplay

# %%
def plot(episode, scores, average_scores, current_step, i=True):
    if i:
        plt.xlabel("Episodes")
        plt.ylabel("Scores")
        plt.title('Training...')
        plt.plot(scores, label='Scores')
        # plot average score
        plt.plot(average_scores, label='Average')
        plt.legend()
        plt.grid()
        plt.pause(0.001)
        plt.show()
        print("Episode: {} - Current step: {} - Score: {} - Average score: {} - Record: {}".format(episode, current_step, scores[-1], round(average_scores[-1], 2), max(scores)))
        is_ipython = 'inline' in matplotlib.get_backend()
        if is_ipython:
            ipythondisplay.clear_output(wait=True)
    else: print("Episode: {} - Current step: {} - Score: {} - Average score: {} - Record: {}".format(episode, current_step, scores[-1], round(average_scores[-1], 2), max(scores)))

def get_average_scores(scores, num):
    if len(scores) > num:
        return np.average(scores[-num:])
    else:
        return np.average(scores)

# %%
env_name = 'InvertedDoublePendulum-v2'
env = gym.make(env_name)
# env.action_space.sample()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\mujoco\mujoco_env.py:12, in <module>
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=10'>11</a> try:
# ---> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=11'>12</a>     import mujoco_py
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=12'>13</a> except ImportError as e:
#
# ModuleNotFoundError: No module named 'mujoco_py'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# d:\ai\test.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/ai/test.ipynb#ch0000002?line=0'>1</a> env_name = 'InvertedDoublePendulum-v2'
# ----> <a href='vscode-notebook-cell:/d%3A/ai/test.ipynb#ch0000002?line=1'>2</a> env = gym.make(env_name)
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\registration.py:235, in make(id, **kwargs)
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=233'>234</a> def make(id, **kwargs):
# --> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=234'>235</a>     return registry.make(id, **kwargs)
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=126'>127</a>     logger.info("Making new env: %s", path)
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=127'>128</a> spec = self.spec(path)
# --> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=128'>129</a> env = spec.make(**kwargs)
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=129'>130</a> return env
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\registration.py:89, in EnvSpec.make(self, **kwargs)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=86'>87</a>     env = self.entry_point(**_kwargs)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=87'>88</a> else:
# ---> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=88'>89</a>     cls = load(self.entry_point)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=89'>90</a>     env = cls(**_kwargs)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=91'>92</a> # Make the environment aware of which spec it came from.
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\registration.py:27, in load(name)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=24'>25</a> def load(name):
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=25'>26</a>     mod_name, attr_name = name.split(":")
# ---> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=26'>27</a>     mod = importlib.import_module(mod_name)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=27'>28</a>     fn = getattr(mod, attr_name)
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/registration.py?line=28'>29</a>     return fn
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=123'>124</a>             break
#     <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=124'>125</a>         level += 1
# --> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=125'>126</a> return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\mujoco\__init__.py:1, in <module>
# ----> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/__init__.py?line=0'>1</a> from gym.envs.mujoco.mujoco_env import MujocoEnv
#       <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/__init__.py?line=2'>3</a> # ^^^^^ so that user gets the correct error
#       <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/__init__.py?line=3'>4</a> # message if mujoco is not installed correctly
#       <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/__init__.py?line=4'>5</a> from gym.envs.mujoco.ant import AntEnv
#
# File c:\Users\Boba.vn\AppData\Local\Programs\Python\Python310\lib\site-packages\gym\envs\mujoco\mujoco_env.py:14, in <module>
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=11'>12</a>     import mujoco_py
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=12'>13</a> except ImportError as e:
# ---> <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=13'>14</a>     raise error.DependencyNotInstalled(
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=14'>15</a>         "{}. (HINT: you need to install mujoco_py, and also perform the setup instructions here: https://github.com/openai/mujoco-py/.)".format(
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=15'>16</a>             e
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=16'>17</a>         )
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=17'>18</a>     )
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=19'>20</a> DEFAULT_SIZE = 500
#      <a href='file:///c%3A/Users/Boba.vn/AppData/Local/Programs/Python/Python310/lib/site-packages/gym/envs/mujoco/mujoco_env.py?line=22'>23</a> def convert_observation_to_space(observation):
#
# DependencyNotInstalled: No module named 'mujoco_py'. (HINT: you need to install mujoco_py, and also perform the setup instructions here: https://github.com/openai/mujoco-py/.)
